# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | lisakovsk
# Processing Record 5 of Set 1 | manzhouli
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | te anau
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | norman wells
# Processing Record 11 of Set 1 | luoyang
# Processing Record 12 of Set 1 | praia
# Processing Record 13 of Set 1 | vestmanna
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | geraldton
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | santa vitoria do palmar
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | hasaki
# Processing Record 23 of Set 1 | lakhnadon
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | nicoya
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | mandalgovi
# Processing Record 29 of Set 1 | zalantun
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | bodden town
# Processing Record 32 of Set 1 | chokurdakh
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | nizwa
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | george town
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | bandarbeyla
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | mount isa
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | luena
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | kruisfontein
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | novyy urengoy
# Processing Record 2 of Set 2 | canto do buriti
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | eyl
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | mehamn
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | erdenet
# Processing Record 16 of Set 2 | singaraja
# Processing Record 17 of Set 2 | korla
# Processing Record 18 of Set 2 | balimo
# City not found. Skipping...
# Processing Record 19 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 2 | rudnogorsk
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | lubbock
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | quatre cocos
# Processing Record 26 of Set 2 | dingle
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | srednekolymsk
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | leningradskiy
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | kloulklubed
# Processing Record 33 of Set 2 | pentecoste
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | octeville
# Processing Record 38 of Set 2 | ahipara
# Processing Record 39 of Set 2 | dindori
# Processing Record 40 of Set 2 | cairns
# Processing Record 41 of Set 2 | golden
# Processing Record 42 of Set 2 | fort nelson
# Processing Record 43 of Set 2 | mpongwe
# Processing Record 44 of Set 2 | dehloran
# Processing Record 45 of Set 2 | rexburg
# Processing Record 46 of Set 2 | asfi
# Processing Record 47 of Set 2 | margate
# Processing Record 48 of Set 2 | samarai
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | oranjemund
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 3 | baiao
# Processing Record 4 of Set 3 | camacha
# Processing Record 5 of Set 3 | atar
# Processing Record 6 of Set 3 | totolapa
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | arrecife
# Processing Record 9 of Set 3 | kidal
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | santiago del estero
# Processing Record 12 of Set 3 | gizo
# Processing Record 13 of Set 3 | stornoway
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | tiarei
# Processing Record 16 of Set 3 | corinto
# Processing Record 17 of Set 3 | la palma
# Processing Record 18 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 3 | bambous virieux
# Processing Record 20 of Set 3 | sawakin
# Processing Record 21 of Set 3 | kapuskasing
# Processing Record 22 of Set 3 | yongchang
# Processing Record 23 of Set 3 | rundu
# Processing Record 24 of Set 3 | vardo
# Processing Record 25 of Set 3 | eydhafushi
# Processing Record 26 of Set 3 | cap malheureux
# Processing Record 27 of Set 3 | viesca
# Processing Record 28 of Set 3 | yulara
# Processing Record 29 of Set 3 | becerril
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | savannah bight
# Processing Record 33 of Set 3 | port alfred
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 3 | hofn
# Processing Record 37 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 3 | mandiana
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | poltavka
# Processing Record 41 of Set 3 | vestmannaeyjar
# Processing Record 42 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 3 | lata
# Processing Record 44 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 3 | madison
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | henties bay
# Processing Record 48 of Set 3 | umm lajj
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | gongzhuling
# Processing Record 1 of Set 4 | mogadishu
# Processing Record 2 of Set 4 | comodoro rivadavia
# Processing Record 3 of Set 4 | abancay
# Processing Record 4 of Set 4 | porto novo
# Processing Record 5 of Set 4 | demyansk
# Processing Record 6 of Set 4 | axim
# Processing Record 7 of Set 4 | najran
# Processing Record 8 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 9 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 4 | rahuri
# Processing Record 11 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | orguz
# Processing Record 16 of Set 4 | constitucion
# Processing Record 17 of Set 4 | takoradi
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | hithadhoo
# Processing Record 20 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 4 | ahero
# Processing Record 22 of Set 4 | ulaanbaatar
# Processing Record 23 of Set 4 | grindavik
# Processing Record 24 of Set 4 | neuquen
# Processing Record 25 of Set 4 | angoche
# Processing Record 26 of Set 4 | visby
# Processing Record 27 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 4 | salina cruz
# Processing Record 29 of Set 4 | shitanjing
# Processing Record 30 of Set 4 | ushtobe
# Processing Record 31 of Set 4 | azpeitia
# Processing Record 32 of Set 4 | broken hill
# Processing Record 33 of Set 4 | gunjur
# Processing Record 34 of Set 4 | yumen
# Processing Record 35 of Set 4 | nikolskoye
# Processing Record 36 of Set 4 | port-cartier
# Processing Record 37 of Set 4 | sola
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | talcahuano
# Processing Record 40 of Set 4 | yorosso
# Processing Record 41 of Set 4 | beringovskiy
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | balkhash
# Processing Record 45 of Set 4 | matay
# Processing Record 46 of Set 4 | raudeberg
# Processing Record 47 of Set 4 | imeni poliny osipenko
# Processing Record 48 of Set 4 | bonavista
# Processing Record 49 of Set 4 | araouane
# Processing Record 50 of Set 4 | andros town
# Processing Record 1 of Set 5 | otane
# Processing Record 2 of Set 5 | champerico
# Processing Record 3 of Set 5 | barrow
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | puerto ayacucho
# Processing Record 8 of Set 5 | havoysund
# Processing Record 9 of Set 5 | ilovlya
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | vila velha
# Processing Record 12 of Set 5 | isangel
# Processing Record 13 of Set 5 | nadvoitsy
# Processing Record 14 of Set 5 | riyadh
# Processing Record 15 of Set 5 | wonthaggi
# Processing Record 16 of Set 5 | pitimbu
# Processing Record 17 of Set 5 | swan hill
# Processing Record 18 of Set 5 | biak
# Processing Record 19 of Set 5 | tabou
# Processing Record 20 of Set 5 | chapais
# Processing Record 21 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 5 | boyolangu
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | segezha
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | huilong
# Processing Record 27 of Set 5 | baruun-urt
# Processing Record 28 of Set 5 | inongo
# Processing Record 29 of Set 5 | nouakchott
# Processing Record 30 of Set 5 | canutama
# Processing Record 31 of Set 5 | shilovo
# Processing Record 32 of Set 5 | ketchikan
# Processing Record 33 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 5 | pontes e lacerda
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | hervey bay
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | gari
# Processing Record 39 of Set 5 | conceicao do araguaia
# Processing Record 40 of Set 5 | karratha
# Processing Record 41 of Set 5 | aykhal
# Processing Record 42 of Set 5 | tatawin
# Processing Record 43 of Set 5 | eugene
# Processing Record 44 of Set 5 | kambove
# Processing Record 45 of Set 5 | churapcha
# Processing Record 46 of Set 5 | kintampo
# Processing Record 47 of Set 5 | chuy
# Processing Record 48 of Set 5 | dongsheng
# Processing Record 49 of Set 5 | vastervik
# City not found. Skipping...
# Processing Record 50 of Set 5 | saint anthony
# Processing Record 1 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 6 | jilin
# Processing Record 3 of Set 6 | poum
# Processing Record 4 of Set 6 | mujiayingzi
# Processing Record 5 of Set 6 | kanniyakumari
# Processing Record 6 of Set 6 | chimbote
# Processing Record 7 of Set 6 | bhongaon
# Processing Record 8 of Set 6 | batemans bay
# Processing Record 9 of Set 6 | sao jose da coroa grande
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | scarborough
# Processing Record 12 of Set 6 | arraial do cabo
# Processing Record 13 of Set 6 | yambio
# Processing Record 14 of Set 6 | maracanau
# Processing Record 15 of Set 6 | jiujiang
# Processing Record 16 of Set 6 | luderitz
# Processing Record 17 of Set 6 | parrita
# Processing Record 18 of Set 6 | clarence town
# Processing Record 19 of Set 6 | prince rupert
# Processing Record 20 of Set 6 | marawi
# Processing Record 21 of Set 6 | dzhebariki-khaya
# Processing Record 22 of Set 6 | trinidad
# Processing Record 23 of Set 6 | bogorodskoye
# Processing Record 24 of Set 6 | mitsamiouli
# Processing Record 25 of Set 6 | katobu
# Processing Record 26 of Set 6 | hay river
# Processing Record 27 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | tromso
# Processing Record 30 of Set 6 | piacabucu
# Processing Record 31 of Set 6 | teknaf
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | kudahuvadhoo
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | eenhana
# Processing Record 36 of Set 6 | sisimiut
# Processing Record 37 of Set 6 | shimoda
# Processing Record 38 of Set 6 | nyurba
# Processing Record 39 of Set 6 | juegang
# Processing Record 40 of Set 6 | alexandria
# Processing Record 41 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | port macquarie
# Processing Record 44 of Set 6 | monte escobedo
# Processing Record 45 of Set 6 | nemuro
# Processing Record 46 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 47 of Set 6 | bilma
# Processing Record 48 of Set 6 | okahandja
# Processing Record 49 of Set 6 | bentiu
# Processing Record 50 of Set 6 | biltine
# Processing Record 1 of Set 7 | horsham
# Processing Record 2 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 7 | cidreira
# Processing Record 5 of Set 7 | waldoboro
# Processing Record 6 of Set 7 | quarai
# Processing Record 7 of Set 7 | waingapu
# Processing Record 8 of Set 7 | kahului
# Processing Record 9 of Set 7 | ahuimanu
# Processing Record 10 of Set 7 | tiksi
# Processing Record 11 of Set 7 | high prairie
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | egra
# Processing Record 14 of Set 7 | at-bashi
# Processing Record 15 of Set 7 | emerald
# Processing Record 16 of Set 7 | acapulco
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | solwezi
# Processing Record 19 of Set 7 | tarakan
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | sojat
# Processing Record 22 of Set 7 | klyuchi
# Processing Record 23 of Set 7 | avera
# Processing Record 24 of Set 7 | hillside
# Processing Record 25 of Set 7 | kirkwall
# Processing Record 26 of Set 7 | qaqortoq
# Processing Record 27 of Set 7 | abu samrah
# Processing Record 28 of Set 7 | westport
# Processing Record 29 of Set 7 | kissidougou
# Processing Record 30 of Set 7 | sokoto
# Processing Record 31 of Set 7 | ambovombe
# Processing Record 32 of Set 7 | bousso
# Processing Record 33 of Set 7 | raurkela
# City not found. Skipping...
# Processing Record 34 of Set 7 | sturgeon falls
# Processing Record 35 of Set 7 | talnakh
# Processing Record 36 of Set 7 | hami
# Processing Record 37 of Set 7 | lavrentiya
# Processing Record 38 of Set 7 | yamada
# Processing Record 39 of Set 7 | alice springs
# Processing Record 40 of Set 7 | visnes
# Processing Record 41 of Set 7 | nador
# Processing Record 42 of Set 7 | taltal
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | havre-saint-pierre
# Processing Record 45 of Set 7 | kirkland lake
# Processing Record 46 of Set 7 | sept-iles
# Processing Record 47 of Set 7 | bilibino
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | kitangari
# Processing Record 50 of Set 7 | kamenka
# Processing Record 1 of Set 8 | rio verde de mato grosso
# Processing Record 2 of Set 8 | tateyama
# Processing Record 3 of Set 8 | berlevag
# Processing Record 4 of Set 8 | samana
# Processing Record 5 of Set 8 | iracoubo
# Processing Record 6 of Set 8 | san francisco del mar
# Processing Record 7 of Set 8 | niceville
# Processing Record 8 of Set 8 | berbera
# Processing Record 9 of Set 8 | port-gentil
# Processing Record 10 of Set 8 | udachnyy
# Processing Record 11 of Set 8 | praia da vitoria
# Processing Record 12 of Set 8 | aldan
# Processing Record 13 of Set 8 | altus
# Processing Record 14 of Set 8 | alyangula
# Processing Record 15 of Set 8 | shenxian
# Processing Record 16 of Set 8 | carutapera
# Processing Record 17 of Set 8 | port hedland
# Processing Record 18 of Set 8 | fairbanks
# Processing Record 19 of Set 8 | mao
# Processing Record 20 of Set 8 | amudat
# Processing Record 21 of Set 8 | casper
# Processing Record 22 of Set 8 | shanghai
# Processing Record 23 of Set 8 | saint-augustin
# Processing Record 24 of Set 8 | hambantota
# Processing Record 25 of Set 8 | cam ranh
# Processing Record 26 of Set 8 | aswan
# Processing Record 27 of Set 8 | bowen
# Processing Record 28 of Set 8 | xingcheng
# Processing Record 29 of Set 8 | jaciara
# Processing Record 30 of Set 8 | gidole
# Processing Record 31 of Set 8 | mnogovershinnyy
# Processing Record 32 of Set 8 | jumla
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | polillo
# Processing Record 35 of Set 8 | beloha
# Processing Record 36 of Set 8 | kitami
# Processing Record 37 of Set 8 | coruripe
# Processing Record 38 of Set 8 | sitka
# Processing Record 39 of Set 8 | fukue
# Processing Record 40 of Set 8 | novomykolayivka
# Processing Record 41 of Set 8 | camocim
# Processing Record 42 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 8 | thyboron
# Processing Record 44 of Set 8 | waddan
# Processing Record 45 of Set 8 | fortuna
# Processing Record 46 of Set 8 | guerrero negro
# Processing Record 47 of Set 8 | nouadhibou
# Processing Record 48 of Set 8 | shingu
# Processing Record 49 of Set 8 | hualmay
# Processing Record 50 of Set 8 | kpandae
# Processing Record 1 of Set 9 | nikolskiy
# Processing Record 2 of Set 9 | nanortalik
# Processing Record 3 of Set 9 | sohag
# Processing Record 4 of Set 9 | tuy hoa
# Processing Record 5 of Set 9 | zhengjiatun
# Processing Record 6 of Set 9 | moose factory
# Processing Record 7 of Set 9 | mayo
# Processing Record 8 of Set 9 | yerbogachen
# Processing Record 9 of Set 9 | tura
# Processing Record 10 of Set 9 | yarovoye
# Processing Record 11 of Set 9 | san quintin
# Processing Record 12 of Set 9 | ishigaki
# Processing Record 13 of Set 9 | coquimbo
# Processing Record 14 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 9 | vigrestad
# Processing Record 16 of Set 9 | mitchell
# Processing Record 17 of Set 9 | njombe
# Processing Record 18 of Set 9 | marsa matruh
# Processing Record 19 of Set 9 | praya
# Processing Record 20 of Set 9 | kavaratti
# Processing Record 21 of Set 9 | griffith
# Processing Record 22 of Set 9 | gambela
# Processing Record 23 of Set 9 | blind river
# Processing Record 24 of Set 9 | collie
# Processing Record 25 of Set 9 | rosetta
# Processing Record 26 of Set 9 | arlit
# Processing Record 27 of Set 9 | betong
# Processing Record 28 of Set 9 | kosa
# Processing Record 29 of Set 9 | bang sai
# Processing Record 30 of Set 9 | taraz
# Processing Record 31 of Set 9 | puerto escondido
# Processing Record 32 of Set 9 | ornskoldsvik
# Processing Record 33 of Set 9 | ginir
# Processing Record 34 of Set 9 | half moon bay
# Processing Record 35 of Set 9 | basarabeasca
# Processing Record 36 of Set 9 | iskateley
# Processing Record 37 of Set 9 | padang
# Processing Record 38 of Set 9 | lom sak
# Processing Record 39 of Set 9 | chara
# Processing Record 40 of Set 9 | itoman
# Processing Record 41 of Set 9 | santa rosalia
# Processing Record 42 of Set 9 | aviles
# Processing Record 43 of Set 9 | hirara
# Processing Record 44 of Set 9 | lubango
# Processing Record 45 of Set 9 | cayenne
# Processing Record 46 of Set 9 | kropotkin
# Processing Record 47 of Set 9 | sur
# Processing Record 48 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 9 | nelson
# Processing Record 50 of Set 9 | puerto el triunfo
# Processing Record 1 of Set 10 | coihaique
# Processing Record 2 of Set 10 | kurchum
# Processing Record 3 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 4 of Set 10 | vaxjo
# Processing Record 5 of Set 10 | staryy nadym
# Processing Record 6 of Set 10 | egvekinot
# Processing Record 7 of Set 10 | caxias
# Processing Record 8 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 10 | kalmunai
# Processing Record 10 of Set 10 | kumbo
# Processing Record 11 of Set 10 | kisangani
# Processing Record 12 of Set 10 | kieta
# Processing Record 13 of Set 10 | gotsu
# Processing Record 14 of Set 10 | piryion
# City not found. Skipping...
# Processing Record 15 of Set 10 | taoudenni
# Processing Record 16 of Set 10 | banloc
# Processing Record 17 of Set 10 | khairpur
# Processing Record 18 of Set 10 | tautira
# Processing Record 19 of Set 10 | zhuhai
# Processing Record 20 of Set 10 | bushehr
# Processing Record 21 of Set 10 | namatanai
# Processing Record 22 of Set 10 | sayyan
# Processing Record 23 of Set 10 | batticaloa
# Processing Record 24 of Set 10 | olafsvik
# Processing Record 25 of Set 10 | naze
# Processing Record 26 of Set 10 | pathein
# Processing Record 27 of Set 10 | majene
# Processing Record 28 of Set 10 | bekhtery
# Processing Record 29 of Set 10 | ankazoabo
# Processing Record 30 of Set 10 | kualakapuas
# Processing Record 31 of Set 10 | mandera
# Processing Record 32 of Set 10 | victor harbor
# Processing Record 33 of Set 10 | mangrol
# Processing Record 34 of Set 10 | dikson
# Processing Record 35 of Set 10 | vila franca do campo
# Processing Record 36 of Set 10 | caborca
# Processing Record 37 of Set 10 | lismore
# Processing Record 38 of Set 10 | lorengau
# Processing Record 39 of Set 10 | pochutla
# Processing Record 40 of Set 10 | yuanping
# Processing Record 41 of Set 10 | serrinha
# Processing Record 42 of Set 10 | japura
# Processing Record 43 of Set 10 | tazovskiy
# Processing Record 44 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 10 | khash
# Processing Record 46 of Set 10 | mocuba
# Processing Record 47 of Set 10 | yaring
# Processing Record 48 of Set 10 | husavik
# Processing Record 49 of Set 10 | bartica
# Processing Record 50 of Set 10 | kanigoro
# Processing Record 1 of Set 11 | port blair
# Processing Record 2 of Set 11 | puerto madryn
# Processing Record 3 of Set 11 | havelock
# Processing Record 4 of Set 11 | lagos
# Processing Record 5 of Set 11 | plettenberg bay
# Processing Record 6 of Set 11 | faya
# Processing Record 7 of Set 11 | nuuk
# Processing Record 8 of Set 11 | salisbury
# Processing Record 9 of Set 11 | nabire
# Processing Record 10 of Set 11 | changji
# Processing Record 11 of Set 11 | gazojak
# Processing Record 12 of Set 11 | kendari
# Processing Record 13 of Set 11 | montevideo
# Processing Record 14 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 11 | verkh-usugli
# Processing Record 16 of Set 11 | umea
# Processing Record 17 of Set 11 | ios
# Processing Record 18 of Set 11 | bati
# Processing Record 19 of Set 11 | laguna
# Processing Record 20 of Set 11 | brokopondo
# Processing Record 21 of Set 11 | vao
# Processing Record 22 of Set 11 | concepcion del oro
# Processing Record 23 of Set 11 | pisco
# Processing Record 24 of Set 11 | omsukchan
# Processing Record 25 of Set 11 | kenai
# Processing Record 26 of Set 11 | vostok
# Processing Record 27 of Set 11 | krasnovishersk
# Processing Record 28 of Set 11 | sao joao da barra
# Processing Record 29 of Set 11 | sherlovaya gora
# Processing Record 30 of Set 11 | antalya
# Processing Record 31 of Set 11 | netanya
# Processing Record 32 of Set 11 | raipur
# Processing Record 33 of Set 11 | charters towers
# Processing Record 34 of Set 11 | kon tum
# Processing Record 35 of Set 11 | ribeira grande
# Processing Record 36 of Set 11 | quelimane
# Processing Record 37 of Set 11 | potgietersrus
# City not found. Skipping...
# Processing Record 38 of Set 11 | opuwo
# Processing Record 39 of Set 11 | maua
# Processing Record 40 of Set 11 | gazli
# Processing Record 41 of Set 11 | aljezur
# Processing Record 42 of Set 11 | dunayivtsi
# City not found. Skipping...
# Processing Record 43 of Set 11 | bama
# Processing Record 44 of Set 11 | acari
# Processing Record 45 of Set 11 | lompoc
# Processing Record 46 of Set 11 | caravelas
# Processing Record 47 of Set 11 | cotonou
# Processing Record 48 of Set 11 | sabya
# Processing Record 49 of Set 11 | ponta delgada
# Processing Record 50 of Set 11 | pokhara
# Processing Record 1 of Set 12 | pevek
# Processing Record 2 of Set 12 | bernay
# Processing Record 3 of Set 12 | zhanaozen
# Processing Record 4 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 5 of Set 12 | emmett
# Processing Record 6 of Set 12 | yekaterinoslavka
# Processing Record 7 of Set 12 | kutum
# Processing Record 8 of Set 12 | mariinsk
# Processing Record 9 of Set 12 | saint-georges
# Processing Record 10 of Set 12 | ganzhou
# Processing Record 11 of Set 12 | pizarro
# Processing Record 12 of Set 12 | cedral
# Processing Record 13 of Set 12 | santiago
# Processing Record 14 of Set 12 | kasempa
# Processing Record 15 of Set 12 | martapura
# Processing Record 16 of Set 12 | college
# Processing Record 17 of Set 12 | kedrovyy
# Processing Record 18 of Set 12 | mporokoso
# Processing Record 19 of Set 12 | katsuura
# Processing Record 20 of Set 12 | tecoanapa
# Processing Record 21 of Set 12 | joao pinheiro
# Processing Record 22 of Set 12 | rio esteban
# Processing Record 23 of Set 12 | helong
# Processing Record 24 of Set 12 | ndele
# Processing Record 25 of Set 12 | marystown
# Processing Record 26 of Set 12 | balaipungut
# Processing Record 27 of Set 12 | progreso
# Processing Record 28 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 12 | baculin
# Processing Record 31 of Set 12 | maldonado
# Processing Record 32 of Set 12 | tokoroa
# Processing Record 33 of Set 12 | ixtapa
# Processing Record 34 of Set 12 | necochea
# Processing Record 35 of Set 12 | novyy oskol
# Processing Record 36 of Set 12 | milyutinskaya
# Processing Record 37 of Set 12 | rong kwang
# Processing Record 38 of Set 12 | puerto leguizamo
# Processing Record 39 of Set 12 | inuvik
# Processing Record 40 of Set 12 | stonewall
# Processing Record 41 of Set 12 | paracatu
# Processing Record 42 of Set 12 | richards bay
# Processing Record 43 of Set 12 | bensonville
# Processing Record 44 of Set 12 | sa kaeo
# Processing Record 45 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 46 of Set 12 | orlik
# Processing Record 47 of Set 12 | perth
# Processing Record 48 of Set 12 | yakeshi
# Processing Record 49 of Set 12 | kushmurun
# Processing Record 50 of Set 12 | panjab
# Processing Record 1 of Set 13 | katherine
# Processing Record 2 of Set 13 | nisia floresta
# Processing Record 3 of Set 13 | saint-joseph
# Processing Record 4 of Set 13 | price
# Processing Record 5 of Set 13 | montepuez
# Processing Record 6 of Set 13 | maykor
# Processing Record 7 of Set 13 | urayasu
# Processing Record 8 of Set 13 | lang suan
# Processing Record 9 of Set 13 | vallenar
# Processing Record 10 of Set 13 | san carlos de bariloche
# Processing Record 11 of Set 13 | jalu
# Processing Record 12 of Set 13 | chontalpa
# Processing Record 13 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 13 | luanda
# Processing Record 15 of Set 13 | karpathos
# Processing Record 16 of Set 13 | oga
# Processing Record 17 of Set 13 | polson
# Processing Record 18 of Set 13 | axixa do tocantins
# City not found. Skipping...
# Processing Record 19 of Set 13 | road town
# Processing Record 20 of Set 13 | pushkino
# Processing Record 21 of Set 13 | walvis bay
# Processing Record 22 of Set 13 | nishihara
# Processing Record 23 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 13 | bafra
# Processing Record 25 of Set 13 | upington
# Processing Record 26 of Set 13 | san joaquin
# Processing Record 27 of Set 13 | urubicha
# Processing Record 28 of Set 13 | mandan
# Processing Record 29 of Set 13 | deori
# Processing Record 30 of Set 13 | riosucio
# Processing Record 31 of Set 13 | abu kamal
# Processing Record 32 of Set 13 | tezu
# Processing Record 33 of Set 13 | qena
# Processing Record 34 of Set 13 | buala
# Processing Record 35 of Set 13 | manthani
# Processing Record 36 of Set 13 | skibbereen
# Processing Record 37 of Set 13 | kungurtug
# Processing Record 38 of Set 13 | mariel
# Processing Record 39 of Set 13 | ojinaga
# Processing Record 40 of Set 13 | koygorodok
# Processing Record 41 of Set 13 | libertador general san martin
# Processing Record 42 of Set 13 | kearney
# Processing Record 43 of Set 13 | virginia beach
# Processing Record 44 of Set 13 | belyy yar
# Processing Record 45 of Set 13 | chokwe
# Processing Record 46 of Set 13 | oktyabrskoye
# Processing Record 47 of Set 13 | damghan
# Processing Record 48 of Set 13 | mount gambier
# Processing Record 49 of Set 13 | yenagoa
# Processing Record 50 of Set 13 | watford
# Processing Record 1 of Set 14 | birao
# Processing Record 2 of Set 14 | dawson creek
# Processing Record 3 of Set 14 | marzuq
# Processing Record 4 of Set 14 | aksarka
# Processing Record 5 of Set 14 | waipawa
# Processing Record 6 of Set 14 | itarema
# Processing Record 7 of Set 14 | pasighat
# Processing Record 8 of Set 14 | souillac
# Processing Record 9 of Set 14 | adrar
# Processing Record 10 of Set 14 | atasu
# Processing Record 11 of Set 14 | sembabule
# Processing Record 12 of Set 14 | nome
# Processing Record 13 of Set 14 | mecca
# Processing Record 14 of Set 14 | krapivinskiy
# Processing Record 15 of Set 14 | beasain
# Processing Record 16 of Set 14 | bardsir
# Processing Record 17 of Set 14 | barroquinha
# Processing Record 18 of Set 14 | grafton
# Processing Record 19 of Set 14 | kazerun
# Processing Record 20 of Set 14 | bethanien
# Processing Record 21 of Set 14 | sydney
# Processing Record 22 of Set 14 | seddon
# Processing Record 23 of Set 14 | fare
# Processing Record 24 of Set 14 | opotiki
# Processing Record 25 of Set 14 | saraland
# Processing Record 26 of Set 14 | erzin
# Processing Record 27 of Set 14 | oistins
# Processing Record 28 of Set 14 | preobrazheniye
# Processing Record 29 of Set 14 | chichihualco
# Processing Record 30 of Set 14 | smithers
# Processing Record 31 of Set 14 | batagay
# Processing Record 32 of Set 14 | san patricio
# Processing Record 33 of Set 14 | mayumba
# Processing Record 34 of Set 14 | balabac
# Processing Record 35 of Set 14 | okhotsk
# Processing Record 36 of Set 14 | rio grande
# Processing Record 37 of Set 14 | lixourion
# Processing Record 38 of Set 14 | boa vista
# Processing Record 39 of Set 14 | hannibal
# Processing Record 40 of Set 14 | touros
# Processing Record 41 of Set 14 | valdemarpils
# Processing Record 42 of Set 14 | rincon de la victoria
# Processing Record 43 of Set 14 | taperoa
# Processing Record 44 of Set 14 | mahibadhoo
# Processing Record 45 of Set 14 | benguela
# Processing Record 46 of Set 14 | datong
# Processing Record 47 of Set 14 | sangmelima
# Processing Record 48 of Set 14 | tchollire
# Processing Record 49 of Set 14 | flin flon
# Processing Record 50 of Set 14 | tanout
# Processing Record 1 of Set 15 | rocha
# Processing Record 2 of Set 15 | saint-francois
# Processing Record 3 of Set 15 | casselman
# Processing Record 4 of Set 15 | ulladulla
# Processing Record 5 of Set 15 | lazaro cardenas
# Processing Record 6 of Set 15 | cururupu
# Processing Record 7 of Set 15 | tanete
# Processing Record 8 of Set 15 | tashara
# Processing Record 9 of Set 15 | stephenville
# Processing Record 10 of Set 15 | kondinskoye
# Processing Record 11 of Set 15 | roseburg
# Processing Record 12 of Set 15 | ligayan
# Processing Record 13 of Set 15 | komsomolskiy
# Processing Record 14 of Set 15 | tabas
# Processing Record 15 of Set 15 | abha
# Processing Record 16 of Set 15 | pringsewu
# Processing Record 17 of Set 15 | aguimes
# Processing Record 18 of Set 15 | kharan
# Processing Record 19 of Set 15 | lumeje
# Processing Record 20 of Set 15 | joshimath
# Processing Record 21 of Set 15 | clermont
# Processing Record 22 of Set 15 | banda aceh
# Processing Record 23 of Set 15 | minna
# Processing Record 24 of Set 15 | coahuayana
# Processing Record 25 of Set 15 | muros
# Processing Record 26 of Set 15 | cockburn town
# Processing Record 27 of Set 15 | novyy urgal
# Processing Record 28 of Set 15 | novikovo
# Processing Record 29 of Set 15 | juneau
# Processing Record 30 of Set 15 | jinchang
# Processing Record 31 of Set 15 | casa nova
# Processing Record 32 of Set 15 | hajos
# Processing Record 33 of Set 15 | shakiso
# Processing Record 34 of Set 15 | vanavara
# Processing Record 35 of Set 15 | port hardy
# Processing Record 36 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 37 of Set 15 | syedove
# Processing Record 38 of Set 15 | pouebo
# Processing Record 39 of Set 15 | brownwood
# Processing Record 40 of Set 15 | douala
# Processing Record 41 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 15 | akureyri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tasiilaq      GL  65.6145  -37.6368     35.76        70         100
# 1        Broome      US  42.2506  -75.8330     45.63        48           1
# 2      Saldanha      ZA -33.0117   17.9442     64.45        92         100
# 3     Lisakovsk      KZ  52.5369   62.4936      4.57        94           8
# 4     Manzhouli      CN  49.6000  117.4333      6.71        86         100
# 5   East London      ZA -33.0153   27.9116     71.98        94         100
# 6         Vaini      TO -21.2000 -175.2000     77.16        94          75
# 7       Te Anau      NZ -45.4167  167.7167     54.52        74          70
# 8     Mahebourg      MU -20.4081   57.7000     79.09        69          20
# 9  Norman Wells      CA  65.2820 -126.8329     -2.16        71          90
#
#    Wind Speed Current Description
# 0       21.14     overcast clouds
# 1        4.00           clear sky
# 2       13.73     overcast clouds
# 3        4.54           clear sky
# 4        4.74     overcast clouds
# 5        3.87       moderate rain
# 6        8.05          light rain
# 7        0.34          light rain
# 8        8.05          few clouds
# 9       16.11          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
